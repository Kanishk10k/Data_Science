# %%
import sys

# %%
a=[]
print(sys.getrefcount(a))
# Out:
# 2

# %%
b=a
print(sys.getrefcount(a))
# Out:
# 3

# %%
del b
print(sys.getrefcount(a))
# Out:
# 2

# %%
import gc

# %%
gc.enable()

# %%
gc.disable()

# %%
gc.collect()
# Out:
# 170

# %%
gc.get_stats()
# Out:
# [{'collections': 194, 'collected': 2060, 'uncollectable': 0},
#  {'collections': 17, 'collected': 388, 'uncollectable': 0},
#  {'collections': 2, 'collected': 188, 'uncollectable': 0}]

# %%
gc.garbage
# Out:
# []

# %%
import gc

class MyObject:
    def __init__(self, name):
        self.name = name
        print(f"Object {self.name} created")

    def __del__(self):
        print(f"Object {self.name} deleted")

# Create circular reference
obj1 = MyObject("obj1")
obj2 = MyObject("obj2")
obj1.ref = obj2
obj2.ref = obj1

del obj1
del obj2

## Manually trigger the garbage collection
gc.collect()
# Out:
# Object obj1 created
# Object obj2 created
# Object obj1 deleted
# Object obj2 deleted
# 27

# %%
def gen_num(n):
    for i in range(n):
        yield i
        
num=gen_num(6)
for n in num:
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
import tracemalloc

def cr_list():
    return [i for i in range(500)]

def main():
    tracemalloc.start()
    cr_list()
    
    snap=tracemalloc.take_snapshot()
    stats=snap.statistics('lineno')
    
    print('[ Top 10]')
    for i in stats[:15]:
        print(i)

# %%
main()
# Out:
# [ Top 10]
# e:\ML Bootcamp Krish Naik\Code\venv\lib\json\decoder.py:353: size=3764 B, count=45, average=84 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\codeop.py:150: size=1964 B, count=25, average=79 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\traitlets\traitlets.py:1514: size=1680 B, count=10, average=168 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\traitlets\traitlets.py:731: size=1480 B, count=21, average=70 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\zmq\sugar\attrsettr.py:45: size=1320 B, count=24, average=55 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\tracemalloc.py:535: size=1240 B, count=3, average=413 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\jupyter_client\session.py:95: size=1239 B, count=8, average=155 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\ipykernel\kernelbase.py:534: size=1184 B, count=3, average=395 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\enum.py:384: size=1136 B, count=4, average=284 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\IPython\core\compilerop.py:174: size=1120 B, count=16, average=70 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\zmq\sugar\socket.py:802: size=1056 B, count=6, average=176 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\traitlets\traitlets.py:1543: size=1041 B, count=15, average=69 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\ipykernel\iostream.py:287: size=952 B, count=5, average=190 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\site-packages\ipykernel\iostream.py:346: size=912 B, count=10, average=91 B
# e:\ML Bootcamp Krish Naik\Code\venv\lib\tracemalloc.py:226: size=832 B, count=2, average=416 B
