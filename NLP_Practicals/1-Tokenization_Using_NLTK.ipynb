# %%
corpus="""Hello Welcome, My name is Kanishk Gupta.
Currently learning NLP! This is a test file. Let's see what
happens, here.
"""

# %%
print(corpus)
# Out:
# Hello Welcome, My name is Kanishk Gupta.
# Currently learning NLP! This is a test file. Let's see what
# happens, here.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
documents
# Out:
# ['Hello Welcome, My name is Kanishk Gupta.',
#  'Currently learning NLP!',
#  'This is a test file.',
#  "Let's see what\nhappens, here."]

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome, My name is Kanishk Gupta.
# Currently learning NLP!
# This is a test file.
# Let's see what
# happens, here.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'Kanishk',
#  'Gupta',
#  '.',
#  'Currently',
#  'learning',
#  'NLP',
#  '!',
#  'This',
#  'is',
#  'a',
#  'test',
#  'file',
#  '.',
#  'Let',
#  "'s",
#  'see',
#  'what',
#  'happens',
#  ',',
#  'here',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'My', 'name', 'is', 'Kanishk', 'Gupta', '.']
# ['Currently', 'learning', 'NLP', '!']
# ['This', 'is', 'a', 'test', 'file', '.']
# ['Let', "'s", 'see', 'what', 'happens', ',', 'here', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'Kanishk',
#  'Gupta',
#  '.',
#  'Currently',
#  'learning',
#  'NLP',
#  '!',
#  'This',
#  'is',
#  'a',
#  'test',
#  'file',
#  '.',
#  'Let',
#  "'",
#  's',
#  'see',
#  'what',
#  'happens',
#  ',',
#  'here',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'My',
#  'name',
#  'is',
#  'Kanishk',
#  'Gupta.',
#  'Currently',
#  'learning',
#  'NLP',
#  '!',
#  'This',
#  'is',
#  'a',
#  'test',
#  'file.',
#  'Let',
#  "'s",
#  'see',
#  'what',
#  'happens',
#  ',',
#  'here',
#  '.']
